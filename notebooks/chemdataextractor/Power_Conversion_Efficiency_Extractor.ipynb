# %%
import logging
import re
import pandas as pd
import urllib
import time

import chemdataextractor as cde
from chemdataextractor import Document
from chemdataextractor.reader import acs,base,cssp,HtmlReader,NlmXmlReader,PdfReader,RscHtmlReader,XmlReader
from chemdataextractor.model import Compound, UvvisSpectrum, UvvisPeak, BaseModel, StringType, ListType, ModelType
from chemdataextractor.parse.common import hyphen,lbrct, dt, rbrct
from chemdataextractor.parse.base import BaseParser
from chemdataextractor.utils import first

from chemdataextractor.parse.actions import strip_stop, merge, join
from chemdataextractor.parse.elements import W, I, T, R, Optional, ZeroOrMore, OneOrMore, Or, And, Not, Any
from chemdataextractor.parse.cem import chemical_name,cem, chemical_label, lenient_chemical_label, solvent_name
from chemdataextractor.doc import Paragraph, Sentence, Caption, Figure,Table, Heading
from chemdataextractor.doc.table import Table, Cell

# %%
#PCE Parser

class Pce(BaseModel):
    value = StringType()
    units = StringType()

Compound.pce_pattern = ListType(ModelType(Pce))

# prefix = abbrv_prefix | words_pref | hyphanated_pref
common_text = R('(\w+)?\D(\D+)+(\w+)?').hide()
units = (W(u'%') | I(u'percent'))(u'units')
value = R(u'\d+(\.\d+)?')(u'value')

abbrv_prefix = (I(u'PCE') | I(u'PCEs') | I(u'pce')).hide()
words_pref = (I(u'power') + I(u'conversion') + I(u'efficiency') | I(u'efﬁciency')).hide()
hyphanated_pref = (I(u'power') + I(u'-') + I('conversion') + I(u'efficiency') | I(u'efﬁciency')).hide()
joined_range = R('^[\+\-–−]?\d+(\.\d+)?[\-–−~∼˜]\d+(\.\d+)?$')('value').add_action(merge)
spaced_range = (R('^[\+\-–−]?\d+(\.\d+)?$') + Optional(units).hide() + (R('^[\-–−~∼˜]$') +
                                                                        R('^[\+\-–−]?\d+(\.\d+)?$') | R('^[\+\-–−]\d+(\.\d+)?$')))('value').add_action(merge)
to_range = (R('^[\+\-–−]?\d+(\.\d+)?$') + Optional(units).hide() + (I('to') +
                                                                    R('^[\+\-–−]?\d+(\.\d+)?$') | R('^[\+\-–−]\d+(\.\d+)?$')))('value').add_action(join)

# prefix = Optional(I('a')).hide() + (Optional(lbrct) + W('PCEs') + Optional(rbrct) | I('power') + Optional(I('conversion')) + Optional((I('efficiency') | I('range'))) + Optional((I('temperature') | I('range')))
#                                     ).hide() + Optional(lbrct + W('PCE') + rbrct) + Optional(W('=') | I('of') | I('was') | I('is') | I('at')).hide() + Optional(I('in') + I('the') + I('range') + Optional(I('of')) | I('about') | ('around') | I('%')).hide()

prefix = Optional(I('a')).hide() + (Optional(lbrct) + abbrv_prefix + Optional(rbrct) | I('power') + Optional(I('conversion')) + Optional((I('efficiency') | I(u'efﬁciency') | I('range') | words_pref)) + Optional((I('temperature') | I('range')))
                                    ).hide() + Optional(lbrct + W('PCE') + rbrct) + Optional (W('thus')) + Optional (W('reached')) + Optional (W('result')) + Optional (W('up')) + Optional(W('=') | W('¼') | I('of') | I('was') | I('is') | I('at') | I('to')).hide() + Optional(I('in') + I('the') + I('range') + Optional(I('of')) | I('about') | ('around') | I('%')).hide()

pce_first  = (words_pref + (Optional(lbrct) + abbrv_prefix + Optional(rbrct)) + ZeroOrMore(common_text) + value + units)(u'pce')
# pce_first = (prefix + ZeroOrMore(common_text) + value + units)(u'pce')
pce_second = (prefix + value + units)(u'pce')
pce_pattern = pce_first | pce_second

class PceParser(BaseParser):
    root = pce_pattern

    def interpret(self, result, start, end):
        compound = Compound(
            pce_pattern=[
                Pce(
                    value=first(result.xpath('./value/text()')),
                    units=first(result.xpath('./units/text()'))
                )
            ]
        )
        yield compound
    
Sentence.parsers.append(PceParser())
Paragraph.parsers.append(PceParser())

# %%
# Sample Sentences For Regex testing

d1 = Paragraph('for annealed device with 93% RR, JSC = 6.28 mA cm−2, VOC = 0.6 V, FF= 39.4%, PCE= 1.8%; for not-annealed device with 90.7% RR, JSC = 3.27 mA cm−2, VOC = 0.62 V, FF= 37.0%, PCE= 0.9%; for annealed device with 90.7% RR, JSC = 3.07 mA cm−2,VOC = 0.61 V, FF= 32.1%, PCE= 0.7%')

d2 = Paragraph('PBDT-DTNT exhibited a much improved PCE of 6.0%')

d3 = Paragraph('the PCE of PBDT-DTNT was further enhanced to 8.4%.')

d4 = Paragraph('P1 was investigated and the best device performance was obtained in an inverted device structure and a PCE value of 2.78% with a Voc of 0.85 V were achieved.')

d5 = Paragraph('Under optimal processing condition, the PCE of device based on P1 was 2.78% with a Voc of 0.85 V, a Jsc of 8.65 mA/cm2 and an FF of 37.8 %')

d6 = Paragraph('DIO showed a PCE of 2.78% ')

d7 = Paragraph('2 Here, by choosing the appropriate electron-rich unit terthiophene as the donor and isoindigo as the acceptor, we synthesized a new alternating polymer, P3TI, that shows PCEs of up to 6.3% in PSCs with PC71BM as the acceptor')

d8 = Paragraph('The PV performance of P3TI was investigated in PSCs in the standard configuration glass/ITO/PEDOT:PSS/P3TI:PC71BM/ LiF/Al. The P3TI:PC71BM weight ratio was optimized from 1:1 to 1:1.5 to 1:2, and the PV characteristics are summarized in Table 1. PSCs were first fabricated with DCB as the processing solvent for the active layer and showed a PCE of 4.8% for the optimized P3TI:PC71BM weight ratio of 1:1.5')

d9 = Paragraph('A PCE of 6.3% with Voc of 0.70 V, a shortcircuit current density (Jsc) of 13.1 mA cm-2, and a decent FF of 0.69 was obtained for devices containing the 1:1.5 blend as the photoactive layer (thickness of 90 nm) and processed with the additive, under AM 1.5G simulated solar light illumination(100 mW cm-2)')

d10 = Paragraph( 'In summary, an easily accessible alternating copolymer of terthiophene and isoindigo, P3TI, was designed and synthesized. The polymer presents a promising absorption spectrum and appropriate HOMO/LUMO positions, leading to PCEs of up to 6.3% in the resulting PSCs. ')

d11 = Paragraph('Hydrogen is literally Power Conversion Energy 5%')

#print(d1.records.serialize()) #Recognized all percentages no Compound given
#print(d2.records.serialize()) #Recognized Compound and Percentage
#print(d3.records.serialize()) # Recognized Name but not percentage
#print(d4.records.serialize())  # Recognized nothing
#print(d5.records.serialize())   # Recognized Nothing
#print(d6.records.serialize())   # Recognized percentage but not Compound
#print(d7.records.serialize())  # Recognized Compounds but not plural form of                                    # property name
#print(d8.records.serialize()) # Cannot attribute Compound to specific PCE value
#print(d9.records.serialize())  # No compound given recognized percentage
#print(d10.records.serialize()) # Recognized Compounds but not plural form of                                    # property name
print(d11.records.serialize()) # Simple example of order Regex looks for (Compound then value then units)
# Out:
# [{'names': ['Hydrogen']}]

# %%
# Using Sentence Tokenization to parse through the whole article and extract relevant compounds to PCE values, eventually can be implemented to the automated method of looping through the files in 'One Compound' Folder

from chemdataextractor.doc import Paragraph
f = open('2.pdf', 'rb') #Extracting pdf article from One Compound folder
doc = Document.from_file(f) 
#a = doc.records.serialize() # Returns the list object [] w/ a dictionary/maps {}
para = doc.elements # Outputs list of paragaph objects
sentence_records = []
for p in para: # stores all sentences from paragraphs
    p.sentences
    #print(p.sentences)
    sentence_records.append(p.records.serialize())
#print(sentence_records)
pce_sentences = []
contains_pce = False 
for sentence in sentence_records: # Everything the sentence contains
    #print(sentence)
    for words in sentence: #everything inside the sentences is broken up into categories based on label
        #print(words)
        for word_label in words:
            if word_label == 'pce_pattern':
                contains_pce = True
    if contains_pce:
        pce_sentences.append(sentence)
        contains_pce = False
for sentence in pce_sentences:
    for words in sentence:
        print(y)

# STOPPING POINT: NEED TO ASSOCIATE THE PCE VALUES WITH A COMPOUND JUST LIKE WHEN WHOLE PAPER IS EXTRACTED WITHOUT SENTENCE TOKENIZATION
# Out:
# {'names': ['PBDT']}
# {'names': ['ITO']}
# {'names': ['PEDOT']}
# {'names': ['Mg']}
# {'names': ['Al']}
# {'names': ['1,8-diiodooc- tane', 'DIO']}
# {'names': ['methanol']}
# {'names': ['PBDT']}
# {'names': ['DIO']}
# {'pce_pattern': [{'value': '9.19', 'units': '%'}]}
# {'pce_pattern': [{'value': '9.12', 'units': '%'}]}
# {'pce_pattern': [{'value': '8.60', 'units': '%'}]}
# {'names': ['PBDT-TS1']}
# {'names': ['PBDT-TS1']}
# {'names': ['PBDT-TS1:PC71BM']}
# {'pce_pattern': [{'value': '9.48', 'units': '%'}]}
# {'names': ['PBDT-TS1'], 'roles': ['product']}
# {'pce_pattern': [{'value': '10', 'units': '%'}]}

# %%
from chemdataextractor.nlp.tokenize import ChemWordTokenizer
from chemdataextractor.doc import Paragraph 
 
para = Paragraph('In addition to grafting side chains, substitution of the carbon atom in selected locations also affects the energy levels of a polymer. In the recent work26, higher values of Voc are observed when ﬂuorine, an atom of high electron afﬁnity, is introduced to the thieno[3,4-b]thiophene unit, a PCE of 6.1% having been demonstrated26. To this end, PBDTTT–C was modiﬁed with a ﬂuorine atom to lower its HOMO level. The structure of the designed and synthesized PBDTTT–CF is shown in Fig. 1a. The HOMO and LUMO of PBDTTT–CF were measured and compared. J–V curves, a signiﬁcant increase in Voc is clearly observed from PBDTTT–E to PBDTTT–CF. AVoc as high as 0.76 V was observed indevicesbasedonPBDTTT–CF.CombinedwithitshighJsc andﬁll factor (FF), a high PCE of 7.38+0.4% (a 5% device variation), measured in more than 75 devices, was achieved in the PBDTTT– CF system, the highest measured PCE being 7.73%. Devices were then encapsulated and sent to the National Renewable Energy Laboratory (NREL) for certiﬁcation.')
ps = para.sentences

for x in ps:
    print(x.records.serialize())

    print('end of sentence')
# Out:
# [{'names': ['carbon']}]
# end of sentence
# [{'names': ['ﬂuorine']}, {'names': ['thieno[3,4-b]thiophene']}, {'pce_pattern': [{'value': '6.1', 'units': '%'}]}]
# end of sentence
# [{'names': ['PBDTTT–C']}, {'names': ['ﬂuorine']}]
# end of sentence
# [{'names': ['PBDTTT']}]
# end of sentence
# [{'names': ['PBDTTT']}]
# end of sentence
# [{'names': ['PBDTTT–E']}, {'names': ['PBDTTT']}]
# end of sentence
# [{'names': ['indevicesbasedonPBDTTT–CF.CombinedwithitshighJsc']}, {'names': ['PBDTTT']}]
# end of sentence
# []
# end of sentence

# %%
# General method of extracting information from full article 
from chemdataextractor.nlp.tokenize import ChemWordTokenizer
from chemdataextractor.doc import Paragraph

f = open('2.pdf', 'rb')
doc = Document.from_file(f)
para = doc.elements # Outputs list of paragaph objects
print(para)
#sentence_records = []
#for p in para: # stores all sentences from paragraphs
    #p.sentences
    #print(p.sentences)
    #sentence_records.append(p.records.serialize())
#print(sentence_records)




#a = doc.records.serialize()
#a
# Out:
# [Paragraph(id=None, references=[], text='Communication'), Paragraph(id=None, references=[], text='pubs.acs.org/cm'), Paragraph(id=None, references=[], text='†,‡'), Paragraph(id=None, references=[], text='†\nShaoqing Zhang,'), Paragraph(id=None, references=[], text='Highly Eﬃcient 2D-Conjugated Benzodithiophene-Based\nPhotovoltaic Polymer with Linear Alkylthio Side Chain\nand Jianhui Hou*,†\nLong Ye,\n†\nState Key Laboratory of Polymer Physics and Chemistry, Beijing National Laboratory for Molecular Sciences, Institute of Chemistry,\nChinese Academy of Sciences, Beijing 100190, China\n‡\nUniversity of Chinese Academy of Sciences, Beijing 100049, China\n*S Supporting Information'), Paragraph(id=None, references=[], text='†\nWenchao Zhao,'), Paragraph(id=None, references=[], text='Huifeng Yao,'), Paragraph(id=None, references=[], text='†,‡'), Paragraph(id=None, references=[], text='R ecently, polymer solar cells (PSCs) have been the subject'), Paragraph(id=None, references=[], text='of extensive study because of their potential applicability\nin lightweight, ﬂexible, colorful and/or transparent large-area\ndevices.1,2 To improve photovoltaic performance of PSCs,\ntremendous eﬀorts have been devoted to designing, synthesiz-\ning and optimizing photovoltaic polymers with superior\nphotovoltaic properties, such as suitable molecular energy\nlevels, broad absorption band, high hole mobility, and so\non.3−12 Since the ﬁrst introduction of 2-alkylthienyl as the\nconjugated side groups in the benzo[1,2-b:4,5-b′]dithiophene\n(BDT) units,13 the alkylthienyl substituted BDT (BDT-T)\nunits have been widely used to construct novel photovoltaic\npolymers14−20 and thereby the power conversion eﬃciencies\n(PCEs) have been boosted to several new heights in the ﬁeld of\nPSCs.20−23 For\ninstance, Chen et al.23 lately reported a\nphotovoltaic polymer (named as PTB7-Th, see Scheme 1a)\nwith superior photovoltaic properties by incorporating the 2-(2-\nethylhexyl)-thienyl group into the BDT unit of the well-known\nphotovoltaic polymer, PTB7.'), Paragraph(id=None, references=[], text='Scheme 1. (a) Molecular Structure of Two Reference\nPolymers and Target Polymer; (b) Synthesis Procedure of\nPBDT-TS1'), Paragraph(id=None, references=[], text='Generally, higher short-circuit current densities (Jsc) and\nimproved PCEs have been achieved in the PSCs based on the\nBDT-T-based conjugated polymers, whereas the open-circuit\nvoltages (Voc) are still limited. Recently, our group developed a\nnovel strategy to promote the Voc of BDT-T-based polymers by\nincorporating the ﬂuorine atom in the BDT-T units.18'), Paragraph(id=None, references=[], text='Alternatively, others have successfully incorporated sulfur\natom in BDT unit and synthesized eﬃcient photovoltaic\npolymers based on alkylthio-substituted BDT with Voc\nexceeding 0.9 V.24,25 Likewise, branched alkylthio was also\nintroduced in BDT-T-based polymer and an improved Voc of\n0.84 V was obtained in the PSCs based on PBDTT-S-TT (see\nScheme 1a).19 As listed in Table 1, the Jsc of these BDT-T-\nbased polymers (PTB7-Th, PBDTT-S-TT) still kept at a\nrelatively low level, which was the limiting factor for further\nimprovement of PCE. That is to say, to simultaneously achieve\nhigh Voc and Jsc is still a great challenge for molecular design of\nnovel photovoltaic polymers until now.'), Paragraph(id=None, references=[], text='Alkyl chains are fundamental units in designing organic or\npolymeric semiconductors\nfor a well balance of close\nintermolecular packing, high crystallinity, and excellent device\nperformance.26−30 As reported, the size and topology (e.g.,\nlinear, branch) of the alkyl chains appended to the polymer\nbackbone was an critical\nfactor impacting the photovoltaic\nparameters of the corresponding PSCs.30−34 Considering that\nthe branched alkyls have positive inﬂuence in keeping good\nsolubility but adverse eﬀect on the structural order and thereby\ncharge transport properties, the nonconjugated  ...

# %%
# Automated Method of looping through 'One Compound' Folder

import os
import pickle

path = "/Users/walid/OneDrive/Documents/GitHub/AutoDataMining/Named Entity Recognition/one_compound"
entries = os.listdir('/Users/walid/OneDrive/Documents/GitHub/AutoDataMining/Named Entity Recognition/one_compound')
counter = 0
docs = []
for file in os.listdir("/Users/walid/OneDrive/Documents/GitHub/AutoDataMining/Named Entity Recognition/one_compound"):
    filename = os.fsdecode(file)
    filepath = os.path.join("/Users/walid/OneDrive/Documents/GitHub/AutoDataMining/Named Entity Recognition/one_compound/", filename)
    doc = Document.from_file(filepath)
    docs.append(doc)
    counter = counter + 1
    print('a')
    if counter > 5:
        break
for doc in docs:
    print(doc.records.serialize())
# Out:
# a
# a
# a
# a
# a
# a
# [{'names': ['poly(2,5-bis(3-tetradecyllthiophen-2- yl)thieno[3,2,- ]thiophene )']}, {'names': ['1)PC(cid']}, {'names': ['4)BM(cid']}, {'names': ['1)SCLP(cid']}, {'names': ['poly-3-hexylthiophene']}, {'names': ['1)2,5-bis(cid:1)3- recombination.9 tetradecyllthiophen-2-yl(cid:2)thieno(cid:3)3,2-b(cid:4)thiophene(cid']}, {'names': ['di-']}, {'names': ['1)SCLC(cid']}, {'names': ['1)Jsc(cid']}, {'names': ['1)Voc(cid']}, {'names': ['1)FF(cid']}, {'names': ['Indium tin oxide']}, {'names': ['1)ITO(cid']}, {'names': ['acetone']}, {'names': ['isopropyl alcohol']}, {'names': ['1)3,4-ethylenedioxythiophene(cid']}, {'names': ['1)styrenesulfonate(cid']}, {'names': ['oxygen']}, {'names': ['1)Nano-C(cid']}, {'names': ['1)PCEs(cid']}, {'names': ['argon']}, {'names': ['1)PL(cid']}, {'names': ['PCBM, ITO']}, {'names': ['di- odes']}, {'names': ['palladium']}, {'names': ['1)HOMO(cid']}, {'names': ['cid : 1)J-V(cid']}, {'names': ['Xe']}, {'names': ['1)AM(cid']}, {'names': ['NREL']}, {'names': ['Si']}, {'names': ['silicon']}, {'names': ['fullerenes']}, {'names': ['1)GCEP(cid']}, {'names': ['1)NDSEG(cid']}, {'names': ['N']}, {'names': ['8C']}, {'names': ['Met']}, {'names': ['16F']}, {'names': ['17L']}, {'names': ['18L']}, {'names': ['polythiophene']}, {'names': ['PCBM.1–5']}, {'names': ['1)pBTTT(cid']}, {'names': ['fullerene']}, {'names': ['ozone']}, {'names': ['1,2-ortho-dichlorobenzene']}, {'names': ['aluminum']}, {'names': ['1)Color online(cid']}, {'names': ['14S'], 'pce_pattern': [{'value': '2.3', 'units': '%'}]}, {'names': ['nitrogen']}, {'names': ['Li']}, {'names': ['PCBM'], 'pce_pattern': [{'value': '2.3', 'units': '%'}]}]
# [{'names': ['STEFFAN COOK2']}, {'names': ['MCCULLOCH3']}, {'names': ['1-(3-methoxycarbonyl)-propyl-1-phenyl-']}, {'names': ['indium']}, {'names': ['tin-oxide']}, {'names': ['(PCBM)10']}, {'names': ['OCH3']}, {'names': ['O']}, {'names': ['Al']}, {'names': ['BL ITO']}, {'names': ['P3HT+PCBM']}, {'names': ['PEDOT']}, {'names': ['IIN']}, {'names': ['quartz']}, {'names': ['O O P']}, {'names': ['IIP']}, {'names': ['400']}, {'names': ['– 2']}, {'names': ['– 4']}, {'names': ['– 6']}, {'names': ['m r o N']}, {'names': ['Hole']}, {'names': ['– 10']}, {'names': ['300']}, {'names': ['blue line']}, {'names': ['(TAS)19,20']}, {'names': ['Mg']}, {'names': ['quartz substrates ( spectrosil B )']}, {'names': ['nitrogen-ﬁlled']}, {'names': ['JEOL']}, {'names': ['buckminsterfullerene']}, {'names': ['LiF']}, {'names': ['1-(3-methoxycarbonyl)-propyl-1-pheny-(6,6)C61']}, {'names': ['Li']}, {'names': ['poly(3-octylthiophene)-ﬁlms']}, {'names': ['Met']}, {'names': ['C60']}, {'names': ['malonic acid diethyl esters']}, {'names': ['poly(9,9-dioctylﬂuorene-co-benzothiadiazole)']}, {'names': ['poly-(3-substituted) thiophenes']}, {'names': ['fulleroid']}, {'names': ['methanofullerene']}, {'names': ['thiophene']}, {'names': ['θ IN', 'θIN']}, {'names': ['θ 2']}, {'names': ['1–s 1–V']}, {'names': ['– 1.0']}, {'names': ['– 0.5']}, {'names': ['nm']}, {'names': ['Mn']}, {'names': ['chlorobenzene']}, {'names': ['polythiophene']}, {'names': ['H']}, {'names': ['2θ']}, {'names': ['D O Δ'], 'pce_pattern': [{'value': '1.8', 'units': '%'}, {'value': '1.3', 'units': '%'}, {'value': '2.1', 'units': '%'}, {'value': '0.7', 'units': '%'}, {'value': '0.9', 'units': '%'}, {'value': '2.4', 'units': '%'}]}, {'names': ['S']}, {'names': ['VOL']}, {'names': ['fullerene']}, {'names': ['PCBM']}, {'names': ['P3HT', 'poly(3-hexylthiophene)']}]
# [{'names': ['Benzodithiophene']}, {'names': ['alkylthienyl']}, {'names': ['PSCs.20−23']}, {'names': ['2-(2- ethylhexyl)-thienyl']}, {'names': ['ﬂuorine']}, {'names': ['sulfur']}, {'names': ['alkylthio-substituted']}, {'names': ['alkyl']}, {'names': ['branched alkyls']}, {'names': ['octyl-based']}, {'names': ['thieno[3,4- b]thiophene', 'TT']}, {'names': ['alkyls']}, {'names': ['2-ethylhexyl']}, {'names': ['octyl']}, {'names': ['PBT7-Th23']}, {'names': ['Pd(PPh3)4']}, {'names': ['Mn']}, {'names': ['ITO']}, {'names': ['PEDOT']}, {'names': ['Mg']}, {'names': ['Al']}, {'names': ['methanol']}, {'names': ['Kato']}, {'names': ['O']}, {'names': ['Tassone']}, {'names': ['Tan']}, {'names': ['F']}, {'names': ['J.-F']}, {'names': ['alkylthio']}, {'names': ['PBDTT-S-TT']}, {'names': ['PBDTT-S-TT.19']}, {'names': ['1,8-diiodooc- tane', 'DIO']}, {'names': ['H']}, {'names': ['PTB7-Th', 'PTB7- Th']}, {'names': ['PBDTTT']}, {'names': ['PTB7-Th PBDTT-S-TT PBDT-TS1a'], 'pce_pattern': [{'value': '9.19', 'units': '%'}, {'value': '9.12', 'units': '%'}, {'value': '8.60', 'units': '%'}]}, {'names': ['PBDT- TS1 : PC71BM', 'PBDT-TS1:PC71BM']}, {'names': ['BDT', 'benzo[1,2-b:4,5-b′]dithiophene', 'BDT-T'], 'pce_pattern': [{'value': '10', 'units': '%'}, {'value': '9.48', 'units': '%'}]}, {'names': ['PBDT-TS1', 'PBDT- TS1'], 'roles': ['product']}, {'names': ['PBDT']}, {'names': ['Li']}]
# [{'names': ['Naphthobisthiadiazole']}, {'names': ['Hiroshima 739-8527']}, {'names': ['cyclopentadithiophene (CDT),5 benzodithiophene (BDT),6']}, {'names': ['indacenodithiophene (IDT)2d,7']}, {'names': ['thiazolothiazole (TzTz),9 thienopyrrole- dione (TPD),6c − e,10 diketopyrrolopyrrole (DPP),11']}, {'names': ['iso- indigo (IID)12']}, {'names': ['BTz-fused heterocycle']}, {'names': ['naphtho[1,2-c:5,6-c′]bis[1,2,5]thiadiazole-']}, {'names': ['BDT']}, {'names': ['3-(2-Decyltetradecyl)-5- trimethylstannylthiophene ( 1 ) and 4,9-dibromonaphtho[1,2- c : 5,6-c′]bis[1,2,5]thiadiazole'], 'labels': ['3']}, {'names': ['bithiophene'], 'labels': ['5']}, {'names': ['benzenes']}, {'names': ['(kDa)a']}, {'names': ['cooling −']}, {'names': ['114']}, {'names': ['2-octyldodecyl']}, {'names': ['3-(2-Octyldodecyl)-5- trimethylstannylthiophene ( 2 ) and 4,7-dibromo-2,1,3-benzothi- diazole'], 'labels': ['6']}, {'names': ['3-methyl- 5-trimethylstannylthiophene']}, {'names': ['methyl']}, {'names': ['NTz2T- Me']}, {'names': ['sulfur']}, {'names': ['thiadiazole']}, {'names': ['hydrogen']}, {'names': ['ELUMO (eV)e']}, {'names': ['EHOMO (eV)e']}, {'names': ['Ag']}, {'names': ['AgCl']}, {'names': ['BTz4T']}, {'names': ['hexamethyldisilazane']}, {'names': ['(HMDS)-']}, {'names': ['1H,1H,2H,2H-perfluorodecyltriethoxysilane']}, {'names': ['( V ) − 12 to − 6 − 12']}, {'names': ['( V ) − 10 to − 2 − 8']}, {'names': ['polymer PNTz4T']}, {'names': ['na 1 : 1 1 : 1.5 1 : 2 1 : 3 1 : 1 1 : 2']}, {'names': ['PNTz4T / PC61BM']}, {'names': ['TzTz-']}, {'names': ['blue line']}, {'names': ['BTz unit.20']}, {'names': ['(POD2T-DTBT),8b']}, {'names': ['polythiophene']}, {'names': ['BTz fused heteroaromatic']}, {'names': ['3-(2-Decyltetradecyl)-5-trimethylstannylthiophene ( 1 ) and 3-(2-octyldodecyl)-5-trimethylstannylthiophene (2),23 4,9- dibromonaphtho[1,2-c:5,6-c′]bis[1,2,5]thiadiazole (3),14 5,5’-bis- (trimethylstannyl)-2,2’-bithiophene,24 4,7-bis(5-bromo-4-(2- octyldodecyl)thiophen-2-yl)benzo[c][1,2,5]thiadiazole']}, {'names': ['deuterated chloroform']}, {'names': ['TOSOH']}, {'names': ['4,9-Bis(4-(2-decyltetradecyl)thiophen-2-yl)naphtho[1,2-c:5,6-c′]- bis[1,2,5]thiadiazole']}, {'names': ['Tetrakis(triphenylphosphine)- palladium(0)']}, {'names': ['C66H104N4S4']}, {'names': ['N-Bromosuccinimide']}, {'names': ['NaHCO3']}, {'names': ['C66H104N4S4Br2']}, {'names': ['C62H92N2S5']}, {'names': ['Huber']}, {'names': ['silicon']}, {'names': ['nitrogen']}, {'names': ['Au']}, {'names': ['I DS']}, {'names': ['WC L']}, {'names': ['ITO']}, {'names': ['acetone']}, {'names': ['isopropanol']}, {'names': ['ozone']}, {'names': ['tetrafluoroethylene']}, {'names': ['Xe']}, {'names': ['morphol-']}, {'names': ['No. 23245041']}, {'names': ['Morin']}, {'names': ['Bronstein']}, {'names': ['Ting']}, {'names': ['Met']}, {'names': ['quaterthiophene']}, {'names': ['polystyrene']}, {'names': ['thiophenes']}, {'names': ['PNTz4T']}, {'names': ['IP (eV)f'], 'pce_pattern': [{'value': '6.3', 'units': '%'}, {'value': '2.6', 'units': '%'}]}, {'names': ['PC61BM'], 'nmr_spectra': [{'nucleus': '13C', 'solvent': 'CDCl3', 'frequency': '100', 'frequency_units': 'MHz', 'peaks': [{'shift': '153.5'}, {'shift': '152.5'}, {'shift': '143.2'}, {'shift': '138.4'}, {'shift': '130.4'}, {'shift': '126.7'}, {'shift': '124.7'}, {'shift': '123.4'}, {'shift': '122.0'}, {'shift': '38.9'}, {'shift': '35.1'}, {'shift': '33.3'}, {'shift': '31.9'}, {'shift': '30.1'}, {'shift': '29.7'}, {'shift': '29.7'}, {'shift': '29.7'}, {'shift': '29.4'}, {'shift': '29.4'}, {'shift': '26.7'}, {'shift': '22.7'}, {'shift': '14.1'}]}]}, {'names': ['POD2T-DTBT']}, {'names': ['THF']}, {'names': ['N2']}, {'names': ['MgSO4']}, {'names': ['silica gel']}, {'names': ['hexane − dichloromethane', 'hexane− dichloromethane']}, {'names': ['ethyl acetate']}, {'names': ['1H']}, {'names': ['2H']}, {'names': ['12H']}, {'names': ['13C']}, {'names': ['dichloromethane']}, {'names': ['tetrakis(triphenylphosphine)palladium(0)']}, {'names': ['argon']}, {'names': ['hydr ...
# [{'names': ['FULL PAPER']}, {'names': ['fullerenes']}, {'names': ['Mg']}, {'names': ['Mg,THF']}, {'names': ['Br 6']}, {'names': ['Toluene']}, {'names': ['Ethylhexyl']}, {'names': ['chlorobenzene']}, {'names': ['Mn']}, {'names': ['polystyrene']}, {'names': ['Graphite, platinum']}, {'names': ['Ag']}, {'names': ['AgCl']}, {'names': ['tetrabutyl ammonium hexafluorophosphate']}, {'names': ['Bu4NPF6']}, {'names': ['acetonitrile']}, {'names': ['ferrocene']}, {'names': ['ferrocenium']}, {'names': ['glassy carbon']}, {'names': ['poly(3,4-ethylenedioxythiophene):poly-(styrenesul- fonate )']}, {'names': ["2,6-Bis(trimethyltin)-4,8-bis(3-ethylhexyloxy-1- phenyl)-benzo[1,2-b:4,5-b']-dithiophene A"]}, {'names': ["4,8-Bis(4-ethylhexyloxy-1-phenyl)-benzo[1,2- b : 4,5-b']-dithiophene ( 7 ) 1-Bromo-4-(2-ethylhexyl- oxy)benzene"]}, {'names': ['magnesium']}, {'names': ["benzo[1,2-b:4,5- b']dithiophene-4,8-dione"]}, {'names': ['SnCl2']}, {'names': ['HCl']}, {'names': ['sodium bicarbonate']}, {'names': ['magnesium sulfate']}, {'names': ['silica gel']}, {'names': ["2,6-Bis(trimethyltin)-4,8-bis(4-ethylhexyloxy-1- phenyl)-benzo[1,2-b:4,5-b']-dithiophene A"]}, {'labels': ['7'], 'roles': ['compound']}, {'labels': ['P1'], 'roles': ['product']}, {'labels': ['M1'], 'roles': ['compound']}, {'labels': ['P2'], 'roles': ['product']}, {'labels': ['M2'], 'roles': ['compound']}, {'names': ['1,2,4-trichlorobenzene']}, {'names': ['PL220 Chro- matograph with linear polystyrene']}, {'names': ['quartz']}, {'names': ['N2']}, {'names': ['isopropyl alcohol']}, {'names': ['oxygen']}, {'names': ['PVP']}, {'names': ['aluminum']}, {'names': ['isopropyl al- cohol']}, {'names': ['V(methanol)∶V(acetic acid)＝100∶1']}, {'names': ['molybdenum oxide ( MoO3 )']}, {'names': ['4 Pa']}, {'names': ['silicon']}, {'names': ['xenon lamp']}, {'names': ['Guangdong 510640'], 'pce_pattern': [{'value': '2.78', 'units': '%'}]}, {'names': ['alkoxylphenyl substituted, naphtho[1,2-c:5,6-c]bis(1,2,5- thiadiazole )'], 'pce_pattern': [{'value': '6.0', 'units': '%'}]}, {'names': ['naphtho[1,2-c:5,6-c]bis(1,2,5-thiadiazole)', 'NT', 'Naphtho[1,2-c:5,6-c]bis(1,2,5-thiadiazole)']}, {'names': ['alkoxylphenyl', 'Alkoxylphenyl']}, {'names': ['OH']}, {'names': ['DMF, K2CO3']}, {'names': ['O 3']}, {'names': ['Pd(PPh3)4']}, {'names': ['M2']}, {'names': ['Sn(CH3)3Cl']}, {'names': ['trichlorobenzene']}, {'names': ['alkylthienyl']}, {'names': ['n-butyllithium']}, {'names': ['n-hexane']}, {'names': ['trimethyltin chloride']}, {'names': ['2H']}, {'names': ['18H']}, {'labels': ['4'], 'roles': ['compound'], 'nmr_spectra': [{'nucleus': '13C', 'solvent': 'CDCl3', 'frequency': '125', 'frequency_units': 'MHz', 'apparatus': 'Bruker AVANCE Digital 600 MHz NMR workstation', 'peaks': [{'shift': '159.29'}, {'shift': '141.97'}, {'shift': '141.65'}, {'shift': '140.79'}, {'shift': '136.51'}, {'shift': '130.41'}, {'shift': '129.33'}, {'shift': '128.51'}, {'shift': '121.19'}, {'shift': '114.88'}, {'shift': '114.43'}, {'shift': '70.35'}, {'shift': '39.02'}, {'shift': '30.20'}, {'shift': '28.70'}, {'shift': '23.57'}, {'shift': '22.70'}, {'shift': '13.72'}, {'shift': '10.76'}, {'shift': '−8.75'}]}, {'nucleus': '1H', 'solvent': 'CDCl3', 'frequency': '600', 'frequency_units': 'MHz', 'apparatus': 'Bruker AVANCE Digital 600 MHz NMR workstation', 'peaks': [{'shift': '7.48'}]}]}, {'names': ['hexane']}, {'names': ['dichloromethane']}, {'names': ['1H']}, {'names': ['CDCl3']}, {'names': ['12H']}, {'names': ['13C']}, {'labels': ['M3'], 'roles': ['compound']}, {'names': ['nitrogen']}, {'names': ['acetone']}, {'names': ['Si']}, {'names': ['H']}, {'names': ['O']}, {'names': ['Br']}, {'names': ['MoO3']}, {'names': ['PEDOT']}, {'names': ['Al']}, {'names': ['PBDT']}, {'names': ["Benzo[1,2-b:4,5-b']dithiophene-4,8-dione ( 3 ), 4,8- bis(3-ethylhexyloxy-1-phenyl)-benzo[1,2-b:4,5-b']di- ( 4 ), 3,7-(di(2-bromo-3-(2-ethylhexyl)-5-thi- thiphene ( M3 ) enyl)-naphtho[1,2-c:5,6-c]-bis[1,2,5]thiadiazole )"], 'nmr_spectra': [{'nucleus': '13C', 'solvent': 'CDCl3' ...
# [{'names': ['O I T A C I N U M M O C']}, {'names': ['[ 1–3 ]']}, {'names': ['polythiophene', 'PT']}, {'names': ['P3HT : [ 6, 6]-phenyl C 71 butyric acid methyl ester']}, {'names': ['P3HT:indene-C 70 bisad-']}, {'names': ['[ 7 ] Besides']}, {'names': ['[ 8–13 ]']}, {'names': ['NC 27695']}, {'names': ['[ 13–15 ]']}, {'names': ['chloroform', 'CF']}, {'names': ['chlorobenzene', 'CB']}, {'names': ['o -DCB )']}, {'names': ['thiophene']}, {'names': ['carboxylates']}, {'names': ['[ 17 ]']}, {'names': ['ϕ ox']}, {'names': ['PEDOT']}, {'names': ['Ca']}, {'names': ['Al']}, {'names': ['ITO']}, {'names': ['indium tin oxide']}, {'names': ['poly(3,4-ethylenedioxythiophene)']}, {'names': ['poly(styrene sulfonate )']}, {'names': ['N ′-dicyclohexylcarbodiimide']}, {'names': ['2-butyloctan-1-ol']}, {'names': ['Zn']}, {'names': ['PPh 3 ( triphenylphosphine )']}, {'names': ['Ni(PPh 3 ) 2 Cl 2']}, {'names': ['COOH']}, {'names': ['CHCl 3 ,']}, {'names': ['toluene']}, {'names': ['Ag+']}, {'names': ['N O I T A C I N U M M O C']}, {'names': ['J sc']}, {'names': ['poly(ethylene terephthalate )', 'PET']}, {'names': ['As a']}, {'names': ['P3HT / PC71BM']}, {'names': ['alkyl']}, {'names': ['[ 19 ] X-rays']}, {'names': ['O']}, {'names': ['[ 20 ]']}, {'names': ['Li, Macromol']}, {'names': ['J. Huo']}, {'names': ['Tan']}, {'names': ['Yu']}, {'names': ['Met']}, {'names': ['Morin']}, {'names': ['Ser']}, {'names': ['Gann']}, {'names': ['Collins']}, {'names': ['N A Polythiophene'], 'pce_pattern': [{'value': '7.2', 'units': '%'}]}, {'names': ['platinum']}, {'names': ['Bu 4 NPF 6 acetonitrile']}, {'names': ['Ag']}, {'names': ['carboxylate']}, {'names': ['DMAP', '4-dimethylaminopyridine']}, {'names': ['NBS', 'N -bromosuccinimide']}, {'names': ['s n e d t n e r r u C']}, {'names': ['ting', 'Ting']}, {'names': ['300']}, {'names': ['S']}, {'names': ['ortho -dichlorobenzene', 'o -DCB']}, {'names': ['N']}, {'names': ['DIO', '1,8-dii- odooctane']}, {'names': ['C O M M U N I C A T I O N'], 'pce_pattern': [{'value': '3.9', 'units': '%'}, {'value': '6.3', 'units': '%'}, {'value': '7.2', 'units': '%'}, {'value': '6.9', 'units': '%'}]}, {'names': ['F']}, {'names': ['H']}, {'names': ['Li']}, {'names': ['P3HT', 'poly(3-hexylthiophene)']}, {'names': ['PDCBT', 'poly[5,5′- bis(2-butyloctyl)-(2,2′-bithiophene)-4,4′-dicarboxylate-alt- 5,5′-2,2′-bithiophene ]']}]

# %%
# Element Tree method might need to continue

from lxml import etree
root = etree.fromstring(fstring, parser=XMLParser(recover=True,encoding=get_encoding(fstring)))

# %%
# Tuning Regex 
# Goal 1: PCE in plural tense
# Goal 2: Full name "Power Conversion Energy"
# Goal 3: Order of presentation (Compound, PCE value, units)

import logging
import re

from chemdataextractor.model import Compound, UvvisSpectrum, UvvisPeak, BaseModel, StringType, ListType, ModelType
from chemdataextractor.parse.common import hyphen
from chemdataextractor.parse.base import BaseParser
from chemdataextractor.utils import first
from chemdataextractor.parse.actions import strip_stop
from chemdataextractor.parse.elements import W, I, T, R, Optional, ZeroOrMore, OneOrMore
from chemdataextractor.parse.cem import chemical_name
from chemdataextractor.doc import Paragraph, Sentence

class Pce(BaseModel):
    value = StringType()
    units = StringType()

Compound.pce_pattern = ListType(ModelType(Pce))

# prefix = abbrv_prefix | words_pref | hyphanated_pref | plural_pref | fullname_pref
common_text = R('(\w+)?\D(\D+)+(\w+)?').hide()
units = (W(u'%') | I(u'percent'))(u'units')
value = R(u'\d+(\.\d+)?')(u'value')

abbrv_prefix = (I(u'PCE') | I(u'PCEs') | I(u'pce')).hide()
words_pref = (I(u'power') + I(u'conversion') + I(u'efficiency') | I(u'efficiency')).hide()
hyphanated_pref = (I(u'power') + I(u'-') + I('conversion') + I(u'efficiency') | I(u'efﬁciency')).hide()
joined_range = R('^[\+\-–−]?\d+(\.\d+)?[\-–−~∼˜]\d+(\.\d+)?$')('value').add_action(merge)
spaced_range = (R('^[\+\-–−]?\d+(\.\d+)?$') + Optional(units).hide() + (R('^[\-–−~∼˜]$') +
                                                                        R('^[\+\-–−]?\d+(\.\d+)?$') | R('^[\+\-–−]\d+(\.\d+)?$')))('value').add_action(merge)
to_range = (R('^[\+\-–−]?\d+(\.\d+)?$') + Optional(units).hide() + (I('to') +
                                                                    R('^[\+\-–−]?\d+(\.\d+)?$') | R('^[\+\-–−]\d+(\.\d+)?$')))('value').add_action(join)

prefix = Optional(I('a')).hide() + (Optional(lbrct) + W('PCEs') + Optional(rbrct) | I('power') + Optional(I('conversion')) + Optional((I('efficiency') | I('range'))) + Optional((I('temperature') | I('range')))
                                    ).hide() + Optional(lbrct + W('PCE') + rbrct) + Optional(W('=') | I('of') | I('was') | I('is') | I('at')).hide() + Optional(I('in') + I('the') + I('range') + Optional(I('of')) | I('about') | ('around') | I('%')).hide()

prefix = Optional(I('a')).hide() + (Optional(lbrct) + abbrv_prefix + Optional(rbrct) | I('power') + Optional(I('conversion')) + Optional((I('efficiency') | I(u'efﬁciency') | I('range') | words_pref)) + Optional((I('temperature') | I('range')))
                                    ).hide() + Optional(lbrct + W('PCE') + rbrct) + Optional (W('thus')) + Optional (W('reached')) + Optional (W('result')) + Optional (W('up')) + Optional(W('=') | W('¼') | I('of') | I('was') | I('is') | I('at') | I('to')).hide() + Optional(I('in') + I('the') + I('range') + Optional(I('of')) | I('about') | ('around') | I('%')).hide()

pce_first  = (words_pref + (Optional(lbrct) + abbrv_prefix + Optional(rbrct)) + ZeroOrMore(common_text) + value + units)(u'pce')
# pce_first = (prefix + ZeroOrMore(common_text) + value + units)(u'pce')
pce_second = (prefix + value + units)(u'pce')
pce_pattern = pce_first | pce_second

class PceParser(BaseParser):
    root = pce_pattern

    def interpret(self, result, start, end):
        compound = Compound(
            pce_pattern=[
                Pce(
                    value=first(result.xpath('./value/text()')),
                    units=first(result.xpath('./units/text()'))
                )
            ]
        )
        yield compound
    
Sentence.parsers.append(PceParser())
Paragraph.parsers.append(PceParser())



# Potenital taggers to add
 #: Regular expression patterns in (regex, tag) tuples.
    patterns = [
        (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),   # cardinal numbers
        (r'(The|the|A|a|An|an)$', 'AT'),   # articles
        (r'.*able$', 'JJ'),                # adjectives
        (r'.*ness$', 'NN'),                # nouns formed from adjectives
        (r'.*ly$', 'RB'),                  # adverbs
        (r'.*s$', 'PCEs or NNS'),                  # plural nouns
        (r'.*ing$', 'VBG'),                # gerunds
        (r'.*ed$', 'VBD'),                 # past tense verbs
        (r'.*', 'NN')                      # nouns (default)
    ]
